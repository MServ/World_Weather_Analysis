# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 0
set_count = 0

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 0 | marsa matruh
# Processing Record 1 of Set 0 | saint-philippe
# Processing Record 2 of Set 0 | bocaiuva
# Processing Record 3 of Set 0 | hermanus
# Processing Record 4 of Set 0 | amberley
# Processing Record 5 of Set 0 | flinders
# Processing Record 6 of Set 0 | ilulissat
# Processing Record 7 of Set 0 | floro
# Processing Record 8 of Set 0 | rikitea
# Processing Record 9 of Set 0 | ushuaia
# Processing Record 10 of Set 0 | darhan
# Processing Record 11 of Set 0 | atuona
# Processing Record 12 of Set 0 | albany
# Processing Record 13 of Set 0 | talnakh
# Processing Record 14 of Set 0 | khatanga
# Processing Record 15 of Set 0 | avarua
# Processing Record 16 of Set 0 | kapaa
# Processing Record 17 of Set 0 | barrow
# Processing Record 18 of Set 0 | kimbe
# Processing Record 19 of Set 0 | buala
# Processing Record 20 of Set 0 | puerto ayora
# Processing Record 21 of Set 0 | severo-kurilsk
# Processing Record 22 of Set 0 | tasiilaq
# Processing Record 23 of Set 0 | adrar
# Processing Record 24 of Set 0 | carnarvon
# Processing Record 25 of Set 0 | mataura
# Processing Record 26 of Set 0 | port elizabeth
# Processing Record 27 of Set 0 | punta arenas
# Processing Record 28 of Set 0 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 0 | bluff
# Processing Record 30 of Set 0 | tuktoyaktuk
# Processing Record 31 of Set 0 | longyearbyen
# Processing Record 32 of Set 0 | bengkulu
# Processing Record 33 of Set 0 | thompson
# Processing Record 34 of Set 0 | trairi
# Processing Record 35 of Set 0 | ruian
# City not found. Skipping...
# Processing Record 36 of Set 0 | cape town
# Processing Record 37 of Set 0 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 0 | diego de almagro
# Processing Record 39 of Set 0 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 0 | norsup
# Processing Record 41 of Set 0 | cabo san lucas
# Processing Record 42 of Set 0 | puerto montt
# Processing Record 43 of Set 0 | chuy
# Processing Record 44 of Set 0 | sao joao da barra
# Processing Record 45 of Set 0 | novouzensk
# Processing Record 46 of Set 0 | pechenga
# Processing Record 47 of Set 0 | hithadhoo
# Processing Record 48 of Set 0 | hilo
# Processing Record 49 of Set 0 | biak
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | mehamn
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | harper
# Processing Record 6 of Set 1 | cockburn town
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | ormara
# Processing Record 9 of Set 1 | gushikawa
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | sinnamary
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | atambua
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | narsaq
# Processing Record 18 of Set 1 | ejido
# Processing Record 19 of Set 1 | tessalit
# Processing Record 20 of Set 1 | hobyo
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | vardo
# Processing Record 26 of Set 1 | shitanjing
# Processing Record 27 of Set 1 | vao
# Processing Record 28 of Set 1 | abbeville
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | paamiut
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | tupik
# Processing Record 33 of Set 1 | agadir
# Processing Record 34 of Set 1 | awjilah
# Processing Record 35 of Set 1 | portland
# Processing Record 36 of Set 1 | simao
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | broken hill
# Processing Record 39 of Set 1 | lucatan
# City not found. Skipping...
# Processing Record 40 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 41 of Set 1 | shubarkuduk
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | coquimbo
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | wanning
# Processing Record 47 of Set 1 | antalaha
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | taunton
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | ouesso
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | seda
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | nuuk
# Processing Record 6 of Set 2 | san quintin
# Processing Record 7 of Set 2 | makokou
# Processing Record 8 of Set 2 | sibolga
# Processing Record 9 of Set 2 | katsuura
# Processing Record 10 of Set 2 | husavik
# Processing Record 11 of Set 2 | saint anthony
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | nanortalik
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | neuquen
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | malanje
# Processing Record 20 of Set 2 | horta
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | sonoita
# Processing Record 23 of Set 2 | jayanca
# Processing Record 24 of Set 2 | kyshtovka
# Processing Record 25 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | hambantota
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | talara
# Processing Record 30 of Set 2 | arlington
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | sabang
# Processing Record 33 of Set 2 | bereda
# Processing Record 34 of Set 2 | ayan
# Processing Record 35 of Set 2 | bubaque
# Processing Record 36 of Set 2 | lienz
# Processing Record 37 of Set 2 | asau
# Processing Record 38 of Set 2 | chernoyerkovskaya
# Processing Record 39 of Set 2 | bellview
# Processing Record 40 of Set 2 | mayo
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | olafsvik
# Processing Record 43 of Set 2 | bonthe
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | axim
# Processing Record 46 of Set 2 | sorland
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | raga
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | lemesos
# City not found. Skipping...
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | alyangula
# Processing Record 5 of Set 3 | lavrentiya
# Processing Record 6 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 3 | taltal
# Processing Record 8 of Set 3 | puttur
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | hofn
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | westport
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | castro
# Processing Record 15 of Set 3 | guaratinga
# Processing Record 16 of Set 3 | saint-pierre
# Processing Record 17 of Set 3 | yeppoon
# Processing Record 18 of Set 3 | brezno
# Processing Record 19 of Set 3 | tazovskiy
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | safaqis
# City not found. Skipping...
# Processing Record 22 of Set 3 | keroka
# Processing Record 23 of Set 3 | shizunai
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | miracema do tocantins
# Processing Record 26 of Set 3 | finschhafen
# Processing Record 27 of Set 3 | cedral
# Processing Record 28 of Set 3 | henties bay
# Processing Record 29 of Set 3 | morant bay
# Processing Record 30 of Set 3 | beringovskiy
# Processing Record 31 of Set 3 | duku
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | zhigansk
# Processing Record 34 of Set 3 | yumen
# Processing Record 35 of Set 3 | kutum
# Processing Record 36 of Set 3 | coihaique
# Processing Record 37 of Set 3 | kupang
# Processing Record 38 of Set 3 | angoche
# Processing Record 39 of Set 3 | manaure
# Processing Record 40 of Set 3 | lazaro cardenas
# Processing Record 41 of Set 3 | greenville
# Processing Record 42 of Set 3 | belchatow
# Processing Record 43 of Set 3 | upata
# Processing Record 44 of Set 3 | waingapu
# Processing Record 45 of Set 3 | guaira
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | kenora
# Processing Record 48 of Set 3 | shimoda
# Processing Record 49 of Set 3 | komsomolskiy
# Processing Record 50 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | honningsvag
# Processing Record 2 of Set 4 | ulaanbaatar
# Processing Record 3 of Set 4 | egvekinot
# Processing Record 4 of Set 4 | pangnirtung
# Processing Record 5 of Set 4 | palencia
# Processing Record 6 of Set 4 | raduzhnyy
# Processing Record 7 of Set 4 | bafra
# Processing Record 8 of Set 4 | freeport
# Processing Record 9 of Set 4 | port-cartier
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 12 of Set 4 | ponta do sol
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | shingu
# Processing Record 15 of Set 4 | jardim
# Processing Record 16 of Set 4 | cozumel
# Processing Record 17 of Set 4 | lata
# Processing Record 18 of Set 4 | jalu
# Processing Record 19 of Set 4 | chapada dos guimaraes
# Processing Record 20 of Set 4 | moose factory
# Processing Record 21 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 4 | bonavista
# Processing Record 23 of Set 4 | bathsheba
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | lipin bor
# Processing Record 26 of Set 4 | baykit
# Processing Record 27 of Set 4 | kintinku
# Processing Record 28 of Set 4 | ust-ishim
# Processing Record 29 of Set 4 | bogotol
# Processing Record 30 of Set 4 | ust-nera
# Processing Record 31 of Set 4 | puerto escondido
# Processing Record 32 of Set 4 | nome
# Processing Record 33 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 4 | dzilam gonzalez
# Processing Record 35 of Set 4 | riyadh
# Processing Record 36 of Set 4 | oistins
# Processing Record 37 of Set 4 | katrineholm
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | sagua la grande
# Processing Record 40 of Set 4 | uchkent
# Processing Record 41 of Set 4 | kamskiye polyany
# Processing Record 42 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 44 of Set 4 | lerwick
# Processing Record 45 of Set 4 | burnie
# Processing Record 46 of Set 4 | valera
# Processing Record 47 of Set 4 | zhicheng
# Processing Record 48 of Set 4 | mount isa
# Processing Record 49 of Set 4 | agua dulce
# Processing Record 50 of Set 4 | probolinggo
# Processing Record 1 of Set 5 | vila velha
# Processing Record 2 of Set 5 | lorengau
# Processing Record 3 of Set 5 | deputatskiy
# Processing Record 4 of Set 5 | cedar city
# Processing Record 5 of Set 5 | banda aceh
# Processing Record 6 of Set 5 | krasnyy chikoy
# Processing Record 7 of Set 5 | helong
# Processing Record 8 of Set 5 | kasongo-lunda
# Processing Record 9 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | pauini
# Processing Record 12 of Set 5 | santa isabel do rio negro
# Processing Record 13 of Set 5 | raca
# Processing Record 14 of Set 5 | kangaatsiaq
# Processing Record 15 of Set 5 | geraldton
# Processing Record 16 of Set 5 | korla
# Processing Record 17 of Set 5 | norman wells
# Processing Record 18 of Set 5 | yashkul
# Processing Record 19 of Set 5 | sovetskiy
# Processing Record 20 of Set 5 | bara
# Processing Record 21 of Set 5 | provideniya
# Processing Record 22 of Set 5 | tchibanga
# Processing Record 23 of Set 5 | richards bay
# Processing Record 24 of Set 5 | las juntas
# Processing Record 25 of Set 5 | port hedland
# Processing Record 26 of Set 5 | ndele
# Processing Record 27 of Set 5 | grand gaube
# Processing Record 28 of Set 5 | benghazi
# Processing Record 29 of Set 5 | luganville
# Processing Record 30 of Set 5 | meulaboh
# Processing Record 31 of Set 5 | leningradskiy
# Processing Record 32 of Set 5 | zyryanovsk
# Processing Record 33 of Set 5 | luderitz
# Processing Record 34 of Set 5 | yerofey pavlovich
# Processing Record 35 of Set 5 | ampanihy
# Processing Record 36 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 5 | chalchihuites
# Processing Record 38 of Set 5 | padang
# Processing Record 39 of Set 5 | margate
# Processing Record 40 of Set 5 | imeni poliny osipenko
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | alice springs
# Processing Record 43 of Set 5 | rosario oeste
# Processing Record 44 of Set 5 | srednekolymsk
# Processing Record 45 of Set 5 | mudgee
# Processing Record 46 of Set 5 | buston
# Processing Record 47 of Set 5 | san patricio
# Processing Record 48 of Set 5 | ahipara
# Processing Record 49 of Set 5 | ossora
# Processing Record 50 of Set 5 | yaan
# Processing Record 1 of Set 6 | torbay
# Processing Record 2 of Set 6 | vilyuysk
# Processing Record 3 of Set 6 | vostok
# Processing Record 4 of Set 6 | uvarovo
# Processing Record 5 of Set 6 | nishihara
# Processing Record 6 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 6 | fairmont
# Processing Record 8 of Set 6 | ostersund
# Processing Record 9 of Set 6 | grafton
# Processing Record 10 of Set 6 | lima
# Processing Record 11 of Set 6 | berlevag
# Processing Record 12 of Set 6 | kasiri
# Processing Record 13 of Set 6 | lethem
# Processing Record 14 of Set 6 | enumclaw
# Processing Record 15 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | auki
# Processing Record 17 of Set 6 | gat
# Processing Record 18 of Set 6 | agdam
# Processing Record 19 of Set 6 | yacuiba
# Processing Record 20 of Set 6 | souillac
# Processing Record 21 of Set 6 | esperance
# Processing Record 22 of Set 6 | east london
# Processing Record 23 of Set 6 | arlit
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | okhotsk
# Processing Record 26 of Set 6 | kawalu
# Processing Record 27 of Set 6 | cherskiy
# Processing Record 28 of Set 6 | rabo de peixe
# Processing Record 29 of Set 6 | ponta delgada
# Processing Record 30 of Set 6 | mahanoro
# Processing Record 31 of Set 6 | bhuban
# Processing Record 32 of Set 6 | grand-santi
# Processing Record 33 of Set 6 | osecina
# Processing Record 34 of Set 6 | yar-sale
# Processing Record 35 of Set 6 | makaryev
# Processing Record 36 of Set 6 | avila
# Processing Record 37 of Set 6 | gillette
# Processing Record 38 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 6 | guatire
# Processing Record 40 of Set 6 | teknaf
# Processing Record 41 of Set 6 | licheng
# Processing Record 42 of Set 6 | yerbogachen
# Processing Record 43 of Set 6 | sindor
# Processing Record 44 of Set 6 | fallon
# Processing Record 45 of Set 6 | belaya gora
# Processing Record 46 of Set 6 | bantry
# Processing Record 47 of Set 6 | elko
# Processing Record 48 of Set 6 | grand haven
# Processing Record 49 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 6 | verkhoyansk
# Processing Record 1 of Set 7 | itaqui
# Processing Record 2 of Set 7 | manyana
# Processing Record 3 of Set 7 | plettenberg bay
# Processing Record 4 of Set 7 | bahia honda
# Processing Record 5 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 6 of Set 7 | klaksvik
# Processing Record 7 of Set 7 | punta alta
# Processing Record 8 of Set 7 | svetlyy
# Processing Record 9 of Set 7 | kalaleh
# Processing Record 10 of Set 7 | fomboni
# Processing Record 11 of Set 7 | bud
# Processing Record 12 of Set 7 | byron bay
# Processing Record 13 of Set 7 | monforte de lemos
# Processing Record 14 of Set 7 | orangeville
# Processing Record 15 of Set 7 | la mana
# Processing Record 16 of Set 7 | velka nad velickou
# Processing Record 17 of Set 7 | olimpia
# Processing Record 18 of Set 7 | mazyr
# Processing Record 19 of Set 7 | mago
# Processing Record 20 of Set 7 | marawi
# Processing Record 21 of Set 7 | anloga
# Processing Record 22 of Set 7 | san nicolas
# Processing Record 23 of Set 7 | dana point
# Processing Record 24 of Set 7 | kieta
# Processing Record 25 of Set 7 | tabalosos
# Processing Record 26 of Set 7 | brynmawr
# Processing Record 27 of Set 7 | coahuayana
# Processing Record 28 of Set 7 | nantucket
# Processing Record 29 of Set 7 | zalantun
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | lagoa
# Processing Record 32 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | masindi
# Processing Record 35 of Set 7 | iwanai
# Processing Record 36 of Set 7 | rascani
# City not found. Skipping...
# Processing Record 37 of Set 7 | vanimo
# Processing Record 38 of Set 7 | moron
# Processing Record 39 of Set 7 | devonport
# Processing Record 40 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 41 of Set 7 | qasigiannguit
# Processing Record 42 of Set 7 | ambalavao
# Processing Record 43 of Set 7 | plastun
# Processing Record 44 of Set 7 | strezhevoy
# Processing Record 45 of Set 7 | mastic beach
# Processing Record 46 of Set 7 | kailua
# Processing Record 47 of Set 7 | pangoa
# Processing Record 48 of Set 7 | maniitsoq
# Processing Record 49 of Set 7 | nouakchott
# Processing Record 50 of Set 7 | jumla
# Processing Record 1 of Set 8 | abashiri
# Processing Record 2 of Set 8 | vestmannaeyjar
# Processing Record 3 of Set 8 | mount gambier
# Processing Record 4 of Set 8 | bull savanna
# Processing Record 5 of Set 8 | daru
# Processing Record 6 of Set 8 | kodiak
# Processing Record 7 of Set 8 | codrington
# Processing Record 8 of Set 8 | haines junction
# Processing Record 9 of Set 8 | umm lajj
# Processing Record 10 of Set 8 | valle de allende
# Processing Record 11 of Set 8 | kavieng
# Processing Record 12 of Set 8 | broome
# Processing Record 13 of Set 8 | port antonio
# Processing Record 14 of Set 8 | markova
# Processing Record 15 of Set 8 | myaundzha
# Processing Record 16 of Set 8 | pokhara
# Processing Record 17 of Set 8 | barreiras
# Processing Record 18 of Set 8 | puerto narino
# Processing Record 19 of Set 8 | adzhamka
# Processing Record 20 of Set 8 | port lavaca
# Processing Record 21 of Set 8 | haapu
# City not found. Skipping...
# Processing Record 22 of Set 8 | grootfontein
# Processing Record 23 of Set 8 | maumere
# Processing Record 24 of Set 8 | yatou
# Processing Record 25 of Set 8 | morondava
# Processing Record 26 of Set 8 | penha
# Processing Record 27 of Set 8 | rio muerto
# Processing Record 28 of Set 8 | severnyy
# Processing Record 29 of Set 8 | almenevo
# City not found. Skipping...
# Processing Record 30 of Set 8 | acapulco
# Processing Record 31 of Set 8 | boffa
# Processing Record 32 of Set 8 | puerto ayacucho
# Processing Record 33 of Set 8 | sobolevo
# Processing Record 34 of Set 8 | praya
# Processing Record 35 of Set 8 | krasnoarmeysk
# Processing Record 36 of Set 8 | biltine
# Processing Record 37 of Set 8 | vila
# Processing Record 38 of Set 8 | tuatapere
# Processing Record 39 of Set 8 | avera
# Processing Record 40 of Set 8 | thunder bay
# Processing Record 41 of Set 8 | tostamaa
# City not found. Skipping...
# Processing Record 42 of Set 8 | kenai
# Processing Record 43 of Set 8 | namatanai
# Processing Record 44 of Set 8 | la ronge
# Processing Record 45 of Set 8 | ewa beach
# Processing Record 46 of Set 8 | blythe
# Processing Record 47 of Set 8 | komyshuvakha
# Processing Record 48 of Set 8 | te anau
# Processing Record 49 of Set 8 | yuxia
# Processing Record 50 of Set 8 | hammerfest
# Processing Record 1 of Set 9 | puerto del rosario
# Processing Record 2 of Set 9 | boguchany
# Processing Record 3 of Set 9 | toamasina
# Processing Record 4 of Set 9 | necochea
# Processing Record 5 of Set 9 | toropets
# Processing Record 6 of Set 9 | high prairie
# Processing Record 7 of Set 9 | novoanninskiy
# Processing Record 8 of Set 9 | chimaltenango
# Processing Record 9 of Set 9 | port keats
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | okrisky
# Processing Record 12 of Set 9 | kumluca
# Processing Record 13 of Set 9 | mbandaka
# Processing Record 14 of Set 9 | kysyl-syr
# Processing Record 15 of Set 9 | rincon
# Processing Record 16 of Set 9 | kruisfontein
# Processing Record 17 of Set 9 | nador
# Processing Record 18 of Set 9 | sola
# Processing Record 19 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 9 | agstafa
# City not found. Skipping...
# Processing Record 21 of Set 9 | santiago de chuco
# Processing Record 22 of Set 9 | sheboygan
# Processing Record 23 of Set 9 | dauphin
# Processing Record 24 of Set 9 | plast
# Processing Record 25 of Set 9 | kahului
# Processing Record 26 of Set 9 | maldonado
# Processing Record 27 of Set 9 | tommot
# Processing Record 28 of Set 9 | aasiaat
# Processing Record 29 of Set 9 | rawson
# Processing Record 30 of Set 9 | huilong
# Processing Record 31 of Set 9 | aykhal
# Processing Record 32 of Set 9 | vila franca do campo
# Processing Record 33 of Set 9 | sao felix do xingu
# Processing Record 34 of Set 9 | kraskino
# Processing Record 35 of Set 9 | batagay-alyta
# Processing Record 36 of Set 9 | half moon bay
# Processing Record 37 of Set 9 | melbu
# Processing Record 38 of Set 9 | luanda
# Processing Record 39 of Set 9 | berezovka
# Processing Record 40 of Set 9 | macaiba
# Processing Record 41 of Set 9 | karratha
# Processing Record 42 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 9 | koudougou
# Processing Record 44 of Set 9 | chihuahua
# Processing Record 45 of Set 9 | southbridge
# Processing Record 46 of Set 9 | davila
# Processing Record 47 of Set 9 | coos bay
# Processing Record 48 of Set 9 | tigil
# Processing Record 49 of Set 9 | pangody
# Processing Record 50 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 10 | zlocieniec
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | makakilo city
# Processing Record 4 of Set 10 | hasaki
# Processing Record 5 of Set 10 | mukhtolovo
# Processing Record 6 of Set 10 | arth
# Processing Record 7 of Set 10 | yenagoa
# Processing Record 8 of Set 10 | aksarka
# Processing Record 9 of Set 10 | conakry
# Processing Record 10 of Set 10 | gamba
# Processing Record 11 of Set 10 | lovozero
# Processing Record 12 of Set 10 | zvishavane
# Processing Record 13 of Set 10 | bay saint louis
# Processing Record 14 of Set 10 | sandnessjoen
# Processing Record 15 of Set 10 | bogale
# Processing Record 16 of Set 10 | abapo
# Processing Record 17 of Set 10 | mandan
# Processing Record 18 of Set 10 | fukue
# Processing Record 19 of Set 10 | alofi
# Processing Record 20 of Set 10 | manicore
# Processing Record 21 of Set 10 | quatre cocos
# Processing Record 22 of Set 10 | fortuna
# Processing Record 23 of Set 10 | chuncheng
# Processing Record 24 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 10 | lopsmarka
# Processing Record 26 of Set 10 | dombarovskiy
# Processing Record 27 of Set 10 | trat
# Processing Record 28 of Set 10 | yuzhno-kurilsk
# Processing Record 29 of Set 10 | fort nelson
# Processing Record 30 of Set 10 | derzhavinsk
# Processing Record 31 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 10 | tamandare
# Processing Record 33 of Set 10 | nizhniy kuranakh
# Processing Record 34 of Set 10 | high level
# Processing Record 35 of Set 10 | tadine
# Processing Record 36 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 10 | catalina
# Processing Record 38 of Set 10 | uniontown
# Processing Record 39 of Set 10 | smirnykh
# Processing Record 40 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 10 | manokwari
# Processing Record 42 of Set 10 | atikokan
# Processing Record 43 of Set 10 | riberalta
# Processing Record 44 of Set 10 | uige
# Processing Record 45 of Set 10 | kapiri mposhi
# Processing Record 46 of Set 10 | parli
# Processing Record 47 of Set 10 | indian head
# Processing Record 48 of Set 10 | purranque
# Processing Record 49 of Set 10 | sao filipe
# Processing Record 50 of Set 10 | yazoo city
# Processing Record 1 of Set 11 | kamaishi
# Processing Record 2 of Set 11 | severodvinsk
# Processing Record 3 of Set 11 | altamira
# Processing Record 4 of Set 11 | tikhmenevo
# City not found. Skipping...
# Processing Record 5 of Set 11 | cam ranh
# Processing Record 6 of Set 11 | harer
# Processing Record 7 of Set 11 | tagusao
# Processing Record 8 of Set 11 | lompoc
# Processing Record 9 of Set 11 | corinto
# Processing Record 10 of Set 11 | terenos
# Processing Record 11 of Set 11 | chimbote
# Processing Record 12 of Set 11 | saint-augustin
# Processing Record 13 of Set 11 | natal
# Processing Record 14 of Set 11 | hyeres
# Processing Record 15 of Set 11 | winnemucca
# Processing Record 16 of Set 11 | areado
# Processing Record 17 of Set 11 | nebolchi
# Processing Record 18 of Set 11 | aklavik
# Processing Record 19 of Set 11 | taloqan
# Processing Record 20 of Set 11 | muncar
# Processing Record 21 of Set 11 | skibbereen
# Processing Record 22 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 11 | mindyak
# Processing Record 25 of Set 11 | hokitika
# Processing Record 26 of Set 11 | saint-francois
# Processing Record 27 of Set 11 | lazo
# Processing Record 28 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 11 | pacific grove
# Processing Record 30 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 31 of Set 11 | governador dix-sept rosado
# Processing Record 32 of Set 11 | buarcos
# Processing Record 33 of Set 11 | guerrero negro
# Processing Record 34 of Set 11 | shentala
# Processing Record 35 of Set 11 | roncade
# Processing Record 36 of Set 11 | wenling
# Processing Record 37 of Set 11 | imbituba
# Processing Record 38 of Set 11 | skjervoy
# Processing Record 39 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 11 | puerto suarez
# Processing Record 41 of Set 11 | sande
# Processing Record 42 of Set 11 | lensk
# Processing Record 43 of Set 11 | rio verde de mato grosso
# Processing Record 44 of Set 11 | yulara
# Processing Record 45 of Set 11 | mahibadhoo
# Processing Record 46 of Set 11 | ambilobe
# Processing Record 47 of Set 11 | tashla
# Processing Record 48 of Set 11 | kirakira
# Processing Record 49 of Set 11 | makung
# City not found. Skipping...
# Processing Record 50 of Set 11 | la joya
# Processing Record 1 of Set 12 | smyrna
# Processing Record 2 of Set 12 | requena
# Processing Record 3 of Set 12 | weligama
# Processing Record 4 of Set 12 | lebedinyy
# Processing Record 5 of Set 12 | wajid
# Processing Record 6 of Set 12 | muros
# Processing Record 7 of Set 12 | naze
# Processing Record 8 of Set 12 | chipinge
# Processing Record 9 of Set 12 | comodoro rivadavia
# Processing Record 10 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 12 | soanierana ivongo
# Processing Record 12 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 12 | mapiripan
# Processing Record 14 of Set 12 | saskylakh
# Processing Record 15 of Set 12 | prince rupert
# Processing Record 16 of Set 12 | la paz
# Processing Record 17 of Set 12 | marathon
# Processing Record 18 of Set 12 | port-gentil
# Processing Record 19 of Set 12 | visby
# Processing Record 20 of Set 12 | fare
# Processing Record 21 of Set 12 | loukhi
# Processing Record 22 of Set 12 | stromness
# Processing Record 23 of Set 12 | paraiso
# Processing Record 24 of Set 12 | beloha
# Processing Record 25 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 26 of Set 12 | tel aviv-yafo
# Processing Record 27 of Set 12 | namibe
# Processing Record 28 of Set 12 | tongren
# Processing Record 29 of Set 12 | parabel
# Processing Record 30 of Set 12 | neiafu
# Processing Record 31 of Set 12 | takaka
# Processing Record 32 of Set 12 | jalalabad
# Processing Record 33 of Set 12 | tautira
# Processing Record 34 of Set 12 | port augusta
# Processing Record 35 of Set 12 | itarema
# Processing Record 36 of Set 12 | chake chake
# Processing Record 37 of Set 12 | waitati
# Processing Record 38 of Set 12 | ranong
# Processing Record 39 of Set 12 | najran
# Processing Record 40 of Set 12 | benjamin constant
# Processing Record 41 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 42 of Set 12 | yaguara
# Processing Record 43 of Set 12 | deniliquin
# Processing Record 44 of Set 12 | sept-iles
# Processing Record 45 of Set 12 | catamarca
# Processing Record 46 of Set 12 | miles city
# Processing Record 47 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 12 | synya
# Processing Record 49 of Set 12 | pringsewu
# Processing Record 50 of Set 12 | cayce
# Processing Record 1 of Set 13 | stornoway
# Processing Record 2 of Set 13 | omutninsk
# Processing Record 3 of Set 13 | braganca
# Processing Record 4 of Set 13 | hami
# Processing Record 5 of Set 13 | boyarka
# Processing Record 6 of Set 13 | kalmunai
# Processing Record 7 of Set 13 | loa janan
# Processing Record 8 of Set 13 | werda
# Processing Record 9 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 13 | denham springs
# Processing Record 11 of Set 13 | eureka
# Processing Record 12 of Set 13 | riviere-du-loup
# Processing Record 13 of Set 13 | the pas
# Processing Record 14 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 13 | devils lake
# Processing Record 16 of Set 13 | linares
# Processing Record 17 of Set 13 | novaya ladoga
# Processing Record 18 of Set 13 | wampusirpi
# City not found. Skipping...
# Processing Record 19 of Set 13 | veraval
# Processing Record 20 of Set 13 | esterhazy
# Processing Record 21 of Set 13 | lahad datu
# Processing Record 22 of Set 13 | acarau
# Processing Record 23 of Set 13 | belyy yar
# Processing Record 24 of Set 13 | bhag
# Processing Record 25 of Set 13 | northam
# Processing Record 26 of Set 13 | ankpa
# Processing Record 27 of Set 13 | dengzhou
# Processing Record 28 of Set 13 | mwinilunga
# Processing Record 29 of Set 13 | upington
# Processing Record 30 of Set 13 | betanzos
# Processing Record 31 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 13 | stykkisholmur
# Processing Record 33 of Set 13 | atyrau
# Processing Record 34 of Set 13 | usinsk
# Processing Record 35 of Set 13 | bam
# Processing Record 36 of Set 13 | taksimo
# Processing Record 37 of Set 13 | tongliao
# Processing Record 38 of Set 13 | turukhansk
# Processing Record 39 of Set 13 | chavakkad
# Processing Record 40 of Set 13 | praia
# Processing Record 41 of Set 13 | caravelas
# Processing Record 42 of Set 13 | nizwa
# Processing Record 43 of Set 13 | kyaikto
# Processing Record 44 of Set 13 | coxim
# Processing Record 45 of Set 13 | kizner
# Processing Record 46 of Set 13 | gornopravdinsk
# Processing Record 47 of Set 13 | othaya
# Processing Record 48 of Set 13 | am timan
# Processing Record 49 of Set 13 | samarai
# Processing Record 50 of Set 13 | liwale
# Processing Record 1 of Set 14 | belem de sao francisco
# Processing Record 2 of Set 14 | jiayuguan
# Processing Record 3 of Set 14 | whitehorse
# Processing Record 4 of Set 14 | nouadhibou
# Processing Record 5 of Set 14 | oshikango
# Processing Record 6 of Set 14 | lumphat
# Processing Record 7 of Set 14 | dalmeny
# Processing Record 8 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 9 of Set 14 | wajima
# Processing Record 10 of Set 14 | vizinga
# Processing Record 11 of Set 14 | csaszartoltes
# Processing Record 12 of Set 14 | ostrovnoy
# Processing Record 13 of Set 14 | palmas
# Processing Record 14 of Set 14 | tecpan
# Processing Record 15 of Set 14 | kalino
# Processing Record 16 of Set 14 | monrovia
# Processing Record 17 of Set 14 | cumberland
# Processing Record 18 of Set 14 | tilichiki
# Processing Record 19 of Set 14 | yian
# City not found. Skipping...
# Processing Record 20 of Set 14 | savelugu
# Processing Record 21 of Set 14 | trujillo
# Processing Record 22 of Set 14 | nisia floresta
# Processing Record 23 of Set 14 | atbasar
# Processing Record 24 of Set 14 | atasu
# Processing Record 25 of Set 14 | amazar
# Processing Record 26 of Set 14 | san andres
# Processing Record 27 of Set 14 | tondi
# Processing Record 28 of Set 14 | novyy svit
# Processing Record 29 of Set 14 | gondanglegi
# Processing Record 30 of Set 14 | wa
# City not found. Skipping...
# Processing Record 31 of Set 14 | wajir
# Processing Record 32 of Set 14 | cananea
# Processing Record 33 of Set 14 | soyo
# Processing Record 34 of Set 14 | samfya
# Processing Record 35 of Set 14 | puerto leguizamo
# Processing Record 36 of Set 14 | chokwe
# Processing Record 37 of Set 14 | evensk
# Processing Record 38 of Set 14 | aksha
# Processing Record 39 of Set 14 | lasa
# Processing Record 40 of Set 14 | tutoia
# Processing Record 41 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 14 | piacabucu
# Processing Record 43 of Set 14 | pitimbu
# Processing Record 44 of Set 14 | kwinana
# Processing Record 45 of Set 14 | latung
# Processing Record 46 of Set 14 | waldkirchen
# Processing Record 47 of Set 14 | ugoofaaru
# Processing Record 48 of Set 14 | hirara
# Processing Record 49 of Set 14 | viedma
# Processing Record 50 of Set 14 | billings
# Processing Record 1 of Set 15 | luau
# Processing Record 2 of Set 15 | eyl
# Processing Record 3 of Set 15 | loknya
# Processing Record 4 of Set 15 | kargil
# Processing Record 5 of Set 15 | pangkalanbuun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Marsa Matruh  31.3525   27.2453      64.4        82          40
# 1  Saint-Philippe -21.3585   55.7679      78.8        73          20
# 2        Bocaiuva -17.1078  -43.8150      87.8        30           0
# 3        Hermanus -34.4187   19.2345      61.0        87         100
# 4        Amberley  39.2048  -84.4280      63.0        48          40
# 5        Flinders -34.5833  150.8552      52.0        84          16
# 6       Ilulissat  69.2167  -51.1000      51.8        40          20
# 7           Floro  61.5996    5.0328      42.8        61          90
# 8         Rikitea -23.1203 -134.9692      77.7        75         100
# 9         Ushuaia -54.8000  -68.3000      57.2        47          40
#
#    Wind Speed Country                 Date Current Description
# 0       14.97      EG  2021-04-25 18:37:22    scattered clouds
# 1       19.57      RE  2021-04-25 18:35:44          light rain
# 2        5.75      BR  2021-04-25 18:37:23           clear sky
# 3        0.67      ZA  2021-04-25 18:30:39     overcast clouds
# 4        6.91      US  2021-04-25 18:37:24    scattered clouds
# 5        1.01      AU  2021-04-25 18:37:24          few clouds
# 6       18.41      GL  2021-04-25 18:32:51          few clouds
# 7       10.36      NO  2021-04-25 18:37:24     overcast clouds
# 8        7.94      PF  2021-04-25 18:37:25          light rain
# 9       18.41      AR  2021-04-25 18:36:33    scattered clouds

# %%
# Make sure the columns are in good order
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
